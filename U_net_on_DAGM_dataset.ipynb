# %% [markdown]
# # [Automatic Defect Inspection with End-to-End Deep Learning](https://www.dlology.com/blog/automatic-defect-inspection-with-end-to-end-deep-learning/) | DLology blog

# %% [markdown]
# In order to satisfy customers' needs, companies have to guarantee the quality of their products, which can often be achieved only by inspection of the finished product. Automatic visual defect detection has the potential to reduce the cost of quality assurance significantly.

# %% [markdown]
# ## Data description

# %% [markdown]
# [`29th Annual Symposium of the German Association for Pattern Recognition, Weakly Supervised Learning for Industrial Optical Inspection, 2007.`](http://resources.mpi-inf.mpg.de/conferences/dagm/2007/prizes.html)

# %% [markdown]
# This dataset is artificially generated, but similar to real world problems. It consists of multiple data sets, each consisting of 1000 images showing the background texture without defects, and of 150 images with one labeled defect each on the background texture. The images in a single data set are very similar, but each data set is generated by a different texture model and defect model.
#
# Not all deviations from the texture are necessarily defects. The algorithm will need to use the weak labels provided during the training phase to learn the properties that characterize a defect.
#
# Below are sample images from 6 data sets. In these examples, defects are weakly labeled by a surrounding ellipse, shown in red.

# %%
# !git clone https://github.com/Tony607/Industrial-Defect-Inspection-segmentation
# %cd /content/Industrial-Defect-Inspection-segmentation
# Out:
# Cloning into 'Industrial-Defect-Inspection-segmentation'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 35 (delta 9), reused 20 (delta 1), pack-reused 0
# Unpacking objects: 100% (35/35), done.
# /content/Industrial-Defect-Inspection-segmentation

# %%
from IPython.display import Image
# %matplotlib inline

# %%
# !wget https://resources.mpi-inf.mpg.de/conference/dagm/2007/Class1_def.zip
# !unzip -q Class1_def.zip -d .
# Out:
# --2021-03-29 07:04:13--  https://resources.mpi-inf.mpg.de/conference/dagm/2007/Class1_def.zip
# Resolving resources.mpi-inf.mpg.de (resources.mpi-inf.mpg.de)... 139.19.206.46
# Connecting to resources.mpi-inf.mpg.de (resources.mpi-inf.mpg.de)|139.19.206.46|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://resources.mpi-inf.mpg.de/conferences/dagm/2007/Class1_def.zip [following]
# --2021-03-29 07:04:14--  https://resources.mpi-inf.mpg.de/conferences/dagm/2007/Class1_def.zip
# Reusing existing connection to resources.mpi-inf.mpg.de:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://conferences.mpi-inf.mpg.de/dagm/2007/Class1_def.zip [following]
# --2021-03-29 07:04:14--  https://conferences.mpi-inf.mpg.de/dagm/2007/Class1_def.zip
# Resolving conferences.mpi-inf.mpg.de (conferences.mpi-inf.mpg.de)... 139.19.206.169
# Connecting to conferences.mpi-inf.mpg.de (conferences.mpi-inf.mpg.de)|139.19.206.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34556484 (33M) [application/zip]
# Saving to: ‘Class1_def.zip’
#
# Class1_def.zip      100%[===================>]  32.96M  13.0MB/s    in 2.5s
#
# 2021-03-29 07:04:18 (13.0 MB/s) - ‘Class1_def.zip’ saved [34556484/34556484]

# %% [markdown]
# ### labeling data

# %% [markdown]
# Defect exists inside an image was bounded with an ellipse. The ellipse-parameters are provided in a separate .txt-file with a format as shown below.

# %% [markdown]
# [filename] \t \n
# [semi-major axis] \t [semi-minor axis] \t [rotation angle] \t
# [x-position of the centre of the ellipsoid] \t [y-position of the centre of the ellipsoid] \n
# [filename] \t ...

# %% [markdown]
# ## Data Preprocessing/Exploration/Inspection

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data_dir = "./Class1_def"

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %% [markdown]
# `coslib` is an old library and is used to plot ellipses in this program. Here we print an image to see what the data looks like.

# %%
from coslib import plot_ellipse_seg_test

plot_ellipse_seg_test(os.path.join(data_dir, "2.png"))

# %%
from coslib import load_images_masks

# %%
X, y = load_images_masks(data_dir, img_type='png', img_format='gray', resize=(256, 256), ellipse=True)

# %%
X.shape
# Out:
# (150, 256, 256, 1)

# %%
y.shape
# Out:
# (150, 256, 256, 1)

# %% [markdown]
# We have stored the images in X and the labels (converted to grayscale images with ellipses) in y.
#
# The shape (a,b,c,d) represents these values:
# * a = image number
# * b,c = pixels of the image
# * d = colour channel (?)

# %%
plt.imshow(X[1,:,:,0], cmap='gray')

# %%
plt.imshow(y[1,:,:,0], cmap='gray')

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (105, 256, 256, 1)

# %%
X_test.shape
# Out:
# (45, 256, 256, 1)

# %% [markdown]
# ## Unet - Fully Convolutional Neuralnetwork

# %% [markdown]
# The u-net is convolutional network architecture for fast and precise segmentation of images. Up to now it has outperformed the prior best method (a sliding-window convolutional network) on the ISBI challenge for segmentation of neuronal structures in electron microscopic stacks. It has won the Grand Challenge for Computer-Automated Detection of Caries in Bitewing Radiography at ISBI 2015, and it has won the Cell Tracking Challenge at ISBI 2015 on the two most challenging transmitted light microscopy categories (Phase contrast and DIC microscopy) by a large margin.

# %%
img_rows = 256
img_cols = 256

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Lambda, Conv2DTranspose, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from scipy.ndimage.measurements import label
import time

# %%
# # Defining a small Unet
# # Smaller Unet defined so it fits in memory


# def get_small_unet():
#     inputs = Input((img_rows, img_cols, 1))
#     inputs_norm = Lambda(lambda x: x/127.5 - 1.)
#     conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
#     conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv1)
#     pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

#     conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
#     conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv2)
#     pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

#     conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool2)
#     conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv3)
#     pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

#     conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool3)
#     conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv4)
#     pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

#     conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool4)
#     conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv5)

#     up6 = concatenate([Conv2DTranspose(64, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
#     conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(up6)
#     conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv6)

#     up7 = concatenate([Conv2DTranspose(32, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
#     conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(up7)
#     conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv7)

#     up8 = concatenate([Conv2DTranspose(16, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
#     conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(up8)
#     conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv8)

#     up9 = concatenate([Conv2DTranspose(8, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
#     conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(up9)
#     conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv9)

#     conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

#     model = Model(inputs=inputs, outputs=conv10)

#     return model

# %%
# BIGGER U-net: 12 Layers


def get_small_unet():
    inputs = Input((img_rows, img_cols, 1))
    inputs_norm = Lambda(lambda x: x/127.5 - 1.)

    conv0 = Conv2D(8, (3, 3), activation='relu', padding='same')(inputs)
    conv0 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv0)
    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)

    conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(pool0)
    conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(64, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(32, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(16, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(8, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv9)

    up10 = concatenate([Conv2DTranspose(4, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv9), conv0], axis=3)
    conv10 = Conv2D(8, (3, 3), activation='relu', padding='same')(up10)
    conv10 = Conv2D(8, (3, 3), activation='relu', padding='same')(conv10)

    conv11 = Conv2D(1, (1, 1), activation='sigmoid')(conv10)

    model = Model(inputs=inputs, outputs=conv11)

    return model

# %%
# #SMALLER U-net: 8 Layers

# def get_small_unet():
#     inputs = Input((img_rows, img_cols, 1))
#     inputs_norm = Lambda(lambda x: x/127.5 - 1.)
#     conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
#     conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv1)
#     pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

#     conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
#     conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv2)
#     pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

#     conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool2)
#     conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv3)
#     pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

#     conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool3)
#     conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv4)
#     # pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
#     #
#     # conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool4)
#     # conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv5)

#     up5 = concatenate([Conv2DTranspose(32, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv4), conv3], axis=3)
#     conv5 = Conv2D(64, (3, 3), activation='relu', padding='same')(up5)
#     conv5 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv5)

#     up6 = concatenate([Conv2DTranspose(16, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv5), conv2], axis=3)
#     conv6 = Conv2D(32, (3, 3), activation='relu', padding='same')(up6)
#     conv6 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv6)

#     up7 = concatenate([Conv2DTranspose(8, kernel_size=(
#         2, 2), strides=(2, 2), padding='same')(conv6), conv1], axis=3)
#     conv7 = Conv2D(16, (3, 3), activation='relu', padding='same')(up7)
#     conv7 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv7)

#     # up9 = concatenate([Conv2DTranspose(8, kernel_size=(
#     #     2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
#     # conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(up9)
#     # conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv9)

#     conv8 = Conv2D(1, (1, 1), activation='sigmoid')(conv7)

#     model = Model(inputs=inputs, outputs=conv8)

#     return model

# %%
model = get_small_unet()

# %%
model.summary()

# %%
def smooth_dice_coeff(smooth=1.):

    smooth = float(smooth)

    # IOU or dice coeff calculation
    def IOU_calc(y_true, y_pred):
            y_true_f = K.flatten(y_true)
            y_pred_f = K.flatten(y_pred)
            intersection = K.sum(y_true_f * y_pred_f)

            return 2*(intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def IOU_calc_loss(y_true, y_pred):
        return -IOU_calc(y_true, y_pred)
    return IOU_calc, IOU_calc_loss

IOU_calc, IOU_calc_loss = smooth_dice_coeff(0.00001)

# %%
model.compile(optimizer=Adam(learning_rate=0.0005), loss=IOU_calc_loss, metrics=[IOU_calc])

# %%
 history = model.fit(X_train, y_train, batch_size=10, epochs=100, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 36s 227ms/step - loss: -0.0651 - IOU_calc: 0.0651 - val_loss: -0.0860 - val_IOU_calc: 0.0974
# Epoch 2/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.0736 - IOU_calc: 0.0738 - val_loss: -0.0914 - val_IOU_calc: 0.1020
# Epoch 3/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.0885 - IOU_calc: 0.0889 - val_loss: -0.1364 - val_IOU_calc: 0.1406
# Epoch 4/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.1578 - IOU_calc: 0.1595 - val_loss: -0.2691 - val_IOU_calc: 0.2816
# Epoch 5/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.2241 - IOU_calc: 0.2256 - val_loss: -0.2977 - val_IOU_calc: 0.2530
# Epoch 6/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.2915 - IOU_calc: 0.2925 - val_loss: -0.3638 - val_IOU_calc: 0.3802
# Epoch 7/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.3828 - IOU_calc: 0.3831 - val_loss: -0.3962 - val_IOU_calc: 0.4345
# Epoch 8/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.2364 - IOU_calc: 0.2372 - val_loss: -0.3733 - val_IOU_calc: 0.3875
# Epoch 9/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.3528 - IOU_calc: 0.3546 - val_loss: -0.4182 - val_IOU_calc: 0.4119
# Epoch 10/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.4248 - IOU_calc: 0.4251 - val_loss: -0.4795 - val_IOU_calc: 0.5183
# Epoch 11/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.4570 - IOU_calc: 0.4567 - val_loss: -0.4791 - val_IOU_calc: 0.4209
# Epoch 12/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.4293 - IOU_calc: 0.4279 - val_loss: -0.4212 - val_IOU_calc: 0.4390
# Epoch 13/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.4999 - IOU_calc: 0.5028 - val_loss: -0.5686 - val_IOU_calc: 0.5188
# Epoch 14/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.6165 - IOU_calc: 0.6175 - val_loss: -0.6029 - val_IOU_calc: 0.7085
# Epoch 15/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.7161 - IOU_calc: 0.7162 - val_loss: -0.8350 - val_IOU_calc: 0.8565
# Epoch 16/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.7563 - IOU_calc: 0.7571 - val_loss: -0.8352 - val_IOU_calc: 0.8624
# Epoch 17/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8046 - IOU_calc: 0.8054 - val_loss: -0.8210 - val_IOU_calc: 0.8304
# Epoch 18/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8148 - IOU_calc: 0.8152 - val_loss: -0.8524 - val_IOU_calc: 0.8834
# Epoch 19/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8384 - IOU_calc: 0.8387 - val_loss: -0.7856 - val_IOU_calc: 0.8577
# Epoch 20/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8133 - IOU_calc: 0.8141 - val_loss: -0.8400 - val_IOU_calc: 0.8665
# Epoch 21/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8103 - IOU_calc: 0.8108 - val_loss: -0.8495 - val_IOU_calc: 0.8919
# Epoch 22/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8465 - IOU_calc: 0.8469 - val_loss: -0.8431 - val_IOU_calc: 0.9018
# Epoch 23/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8552 - IOU_calc: 0.8538 - val_loss: -0.8320 - val_IOU_calc: 0.8781
# Epoch 24/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8265 - IOU_calc: 0.8272 - val_loss: -0.8077 - val_IOU_calc: 0.8549
# Epoch 25/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8317 - IOU_calc: 0.8319 - val_loss: -0.8452 - val_IOU_calc: 0.8978
# Epoch 26/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8082 - IOU_calc: 0.8072 - val_loss: -0.8535 - val_IOU_calc: 0.9012
# Epoch 27/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8363 - IOU_calc: 0.8360 - val_loss: -0.8551 - val_IOU_calc: 0.9058
# Epoch 28/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8480 - IOU_calc: 0.8478 - val_loss: -0.8042 - val_IOU_calc: 0.8348
# Epoch 29/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8428 - IOU_calc: 0.8423 - val_loss: -0.7800 - val_IOU_calc: 0.7956
# Epoch 30/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8466 - IOU_calc: 0.8467 - val_loss: -0.8429 - val_IOU_calc: 0.8934
# Epoch 31/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8720 - IOU_calc: 0.8716 - val_loss: -0.7944 - val_IOU_calc: 0.8155
# Epoch 32/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8674 - IOU_calc: 0.8664 - val_loss: -0.8332 - val_IOU_calc: 0.8576
# Epoch 33/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8615 - IOU_calc: 0.8620 - val_loss: -0.7588 - val_IOU_calc: 0.7663
# Epoch 34/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8109 - IOU_calc: 0.8117 - val_loss: -0.7873 - val_IOU_calc: 0.7926
# Epoch 35/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8191 - IOU_calc: 0.8196 - val_loss: -0.8520 - val_IOU_calc: 0.8838
# Epoch 36/100
# 10/10 [==============================] - 0s 44ms/step - loss: -0.8347 - IOU_calc: 0.8352 - val_loss: -0.8445 - val_IOU_calc: 0.8985
# Epoch 37/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8579 - IOU_calc: 0.8586 - val_loss: -0.8431 - val_IOU_calc: 0.8964
# Epoch 38/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8790 - IOU_calc: 0.8779 - val_loss: -0.8139 - val_IOU_calc: 0.8339
# Epoch 39/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8580 - IOU_calc: 0.8582 - val_loss: -0.8282 - val_IOU_calc: 0.8488
# Epoch 40/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8485 - IOU_calc: 0.8488 - val_loss: -0.8455 - val_IOU_calc: 0.8739
# Epoch 41/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8864 - IOU_calc: 0.8864 - val_loss: -0.8415 - val_IOU_calc: 0.8747
# Epoch 42/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8549 - IOU_calc: 0.8557 - val_loss: -0.8509 - val_IOU_calc: 0.8943
# Epoch 43/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8812 - IOU_calc: 0.8817 - val_loss: -0.8451 - val_IOU_calc: 0.8823
# Epoch 44/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8961 - IOU_calc: 0.8965 - val_loss: -0.7642 - val_IOU_calc: 0.7625
# Epoch 45/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8427 - IOU_calc: 0.8427 - val_loss: -0.8013 - val_IOU_calc: 0.7906
# Epoch 46/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8422 - IOU_calc: 0.8422 - val_loss: -0.8263 - val_IOU_calc: 0.8319
# Epoch 47/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8715 - IOU_calc: 0.8717 - val_loss: -0.8503 - val_IOU_calc: 0.8921
# Epoch 48/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.8791 - IOU_calc: 0.8793 - val_loss: -0.8471 - val_IOU_calc: 0.8943
# Epoch 49/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8678 - IOU_calc: 0.8685 - val_loss: -0.8471 - val_IOU_calc: 0.8755
# Epoch 50/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8855 - IOU_calc: 0.8843 - val_loss: -0.8363 - val_IOU_calc: 0.8735
# Epoch 51/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8955 - IOU_calc: 0.8959 - val_loss: -0.8407 - val_IOU_calc: 0.8610
# Epoch 52/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8983 - IOU_calc: 0.8984 - val_loss: -0.8463 - val_IOU_calc: 0.8983
# Epoch 53/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9069 - IOU_calc: 0.9069 - val_loss: -0.8457 - val_IOU_calc: 0.8723
# Epoch 54/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9126 - IOU_calc: 0.9131 - val_loss: -0.8345 - val_IOU_calc: 0.8727
# Epoch 55/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9110 - IOU_calc: 0.9113 - val_loss: -0.8371 - val_IOU_calc: 0.8478
# Epoch 56/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9124 - IOU_calc: 0.9128 - val_loss: -0.8441 - val_IOU_calc: 0.8876
# Epoch 57/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9094 - IOU_calc: 0.9095 - val_loss: -0.8494 - val_IOU_calc: 0.8906
# Epoch 58/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9110 - IOU_calc: 0.9112 - val_loss: -0.8153 - val_IOU_calc: 0.8177
# Epoch 59/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8992 - IOU_calc: 0.8994 - val_loss: -0.8450 - val_IOU_calc: 0.8945
# Epoch 60/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9129 - IOU_calc: 0.9129 - val_loss: -0.8461 - val_IOU_calc: 0.8787
# Epoch 61/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9086 - IOU_calc: 0.9089 - val_loss: -0.7688 - val_IOU_calc: 0.7789
# Epoch 62/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8768 - IOU_calc: 0.8770 - val_loss: -0.8495 - val_IOU_calc: 0.8744
# Epoch 63/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9010 - IOU_calc: 0.9013 - val_loss: -0.8268 - val_IOU_calc: 0.8782
# Epoch 64/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.8993 - IOU_calc: 0.8995 - val_loss: -0.8430 - val_IOU_calc: 0.8745
# Epoch 65/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9219 - IOU_calc: 0.9216 - val_loss: -0.8356 - val_IOU_calc: 0.8476
# Epoch 66/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9179 - IOU_calc: 0.9179 - val_loss: -0.8484 - val_IOU_calc: 0.8690
# Epoch 67/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9300 - IOU_calc: 0.9302 - val_loss: -0.8482 - val_IOU_calc: 0.8700
# Epoch 68/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9310 - IOU_calc: 0.9312 - val_loss: -0.8449 - val_IOU_calc: 0.8894
# Epoch 69/100
# 10/10 [==============================] - 0s 44ms/step - loss: -0.9283 - IOU_calc: 0.9284 - val_loss: -0.8489 - val_IOU_calc: 0.8898
# Epoch 70/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9143 - IOU_calc: 0.9147 - val_loss: -0.8516 - val_IOU_calc: 0.8656
# Epoch 71/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9365 - IOU_calc: 0.9362 - val_loss: -0.8418 - val_IOU_calc: 0.8484
# Epoch 72/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9346 - IOU_calc: 0.9348 - val_loss: -0.8488 - val_IOU_calc: 0.8685
# Epoch 73/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9374 - IOU_calc: 0.9369 - val_loss: -0.8463 - val_IOU_calc: 0.8834
# Epoch 74/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9366 - IOU_calc: 0.9365 - val_loss: -0.8255 - val_IOU_calc: 0.8391
# Epoch 75/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9238 - IOU_calc: 0.9241 - val_loss: -0.8539 - val_IOU_calc: 0.8972
# Epoch 76/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9266 - IOU_calc: 0.9267 - val_loss: -0.8342 - val_IOU_calc: 0.8507
# Epoch 77/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9374 - IOU_calc: 0.9373 - val_loss: -0.8493 - val_IOU_calc: 0.8778
# Epoch 78/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9466 - IOU_calc: 0.9465 - val_loss: -0.8378 - val_IOU_calc: 0.8681
# Epoch 79/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9255 - IOU_calc: 0.9257 - val_loss: -0.8519 - val_IOU_calc: 0.8944
# Epoch 80/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9394 - IOU_calc: 0.9391 - val_loss: -0.8234 - val_IOU_calc: 0.8218
# Epoch 81/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9154 - IOU_calc: 0.9158 - val_loss: -0.8514 - val_IOU_calc: 0.8939
# Epoch 82/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9418 - IOU_calc: 0.9418 - val_loss: -0.8439 - val_IOU_calc: 0.8782
# Epoch 83/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9458 - IOU_calc: 0.9457 - val_loss: -0.8177 - val_IOU_calc: 0.8224
# Epoch 84/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9327 - IOU_calc: 0.9326 - val_loss: -0.8481 - val_IOU_calc: 0.8958
# Epoch 85/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9354 - IOU_calc: 0.9344 - val_loss: -0.8449 - val_IOU_calc: 0.8658
# Epoch 86/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9365 - IOU_calc: 0.9363 - val_loss: -0.8244 - val_IOU_calc: 0.8687
# Epoch 87/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9266 - IOU_calc: 0.9267 - val_loss: -0.8231 - val_IOU_calc: 0.8331
# Epoch 88/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9430 - IOU_calc: 0.9432 - val_loss: -0.8428 - val_IOU_calc: 0.8795
# Epoch 89/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9428 - IOU_calc: 0.9430 - val_loss: -0.8303 - val_IOU_calc: 0.8384
# Epoch 90/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9471 - IOU_calc: 0.9467 - val_loss: -0.8406 - val_IOU_calc: 0.8762
# Epoch 91/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9440 - IOU_calc: 0.9440 - val_loss: -0.8271 - val_IOU_calc: 0.8370
# Epoch 92/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9471 - IOU_calc: 0.9471 - val_loss: -0.8422 - val_IOU_calc: 0.8748
# Epoch 93/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9529 - IOU_calc: 0.9531 - val_loss: -0.8329 - val_IOU_calc: 0.8638
# Epoch 94/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9516 - IOU_calc: 0.9515 - val_loss: -0.8311 - val_IOU_calc: 0.8795
# Epoch 95/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9522 - IOU_calc: 0.9522 - val_loss: -0.8239 - val_IOU_calc: 0.8532
# Epoch 96/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9538 - IOU_calc: 0.9537 - val_loss: -0.8338 - val_IOU_calc: 0.8818
# Epoch 97/100
# 10/10 [==============================] - 0s 42ms/step - loss: -0.9531 - IOU_calc: 0.9530 - val_loss: -0.8385 - val_IOU_calc: 0.8651
# Epoch 98/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9602 - IOU_calc: 0.9599 - val_loss: -0.8522 - val_IOU_calc: 0.8845
# Epoch 99/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9641 - IOU_calc: 0.9640 - val_loss: -0.8310 - val_IOU_calc: 0.8660
# Epoch 100/100
# 10/10 [==============================] - 0s 43ms/step - loss: -0.9625 - IOU_calc: 0.9625 - val_loss: -0.8410 - val_IOU_calc: 0.8827

# %%
#history = model.fit(X_train, y_train, batch_size = 2, epochs = 25, verbose = 1)

# %% [markdown]
# ## Learning curves

# %%
plt.figure(figsize=(20, 5))
plt.plot(model.history.history['loss'], label='Train loss')
plt.plot(model.history.history['val_loss'], label='Val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %%
plt.figure(figsize=(20, 5))
plt.plot(model.history.history['IOU_calc'], label='Train IOU')
plt.plot(model.history.history['val_IOU_calc'], label='Val IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()

# %% [markdown]
# ## Predict on testing data

# %%
predict = model.predict(X_test)

# %%
import numpy as np
import cv2


def predict_evaluation(pred, image, label):
    '''
    '''
    # transform gray image to rgb
    img = np.array(image, np.uint8)
    rgb_img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    # scale pred and mask's pixel range to 0~255
    im_label = np.array(255*label, dtype=np.uint8)
    im_pred = np.array(255*pred, dtype=np.uint8)

    # transform both of them to rgb
    rgb_label = cv2.cvtColor(im_label, cv2.COLOR_GRAY2RGB)
    rgb_pred = cv2.cvtColor(im_pred, cv2.COLOR_GRAY2RGB)

    rgb_label[:, :, 1:3] = 0*rgb_label[:, :, 1:2]
    rgb_pred[:, :, 0] = 0*rgb_pred[:, :, 0]
    rgb_pred[:, :, 2] = 0*rgb_pred[:, :, 2]

    img_pred = cv2.addWeighted(rgb_img, 1, rgb_pred, 0.3, 0)
    img_label = cv2.addWeighted(rgb_img, 1, rgb_label, 0.3, 0)

    plt.figure(figsize=(10, 10))

    plt.subplot(1, 3, 1)
    plt.imshow(rgb_img)
    plt.title('Original image')
    plt.axis('off')
    plt.subplot(1, 3, 2)
    plt.imshow(img_pred)
    plt.title('Prediction')
    plt.axis('off')
    plt.subplot(1, 3, 3)
    plt.imshow(img_label)
    plt.title('Ground truth')
    plt.axis('off')

# %%
predict_evaluation(predict[30,:,:,0], X_test[30,:,:,0], y_test[30,:,:,0])

# %%
predict_evaluation(predict[1,:,:,0], X_test[1,:,:,0], y_test[1,:,:,0])

# %%
predict_evaluation(predict[2,:,:,0], X_test[2,:,:,0], y_test[2,:,:,0])

# %%
predict_evaluation(predict[3,:,:,0], X_test[3,:,:,0], y_test[3,:,:,0])

# %%
predict_evaluation(predict[4,:,:,0], X_test[4,:,:,0], y_test[4,:,:,0])

# %%
predict_evaluation(predict[5,:,:,0], X_test[5,:,:,0], y_test[5,:,:,0])

# %%
predict_evaluation(predict[6,:,:,0], X_test[6,:,:,0], y_test[6,:,:,0])

# %%
predict_evaluation(predict[7,:,:,0], X_test[7,:,:,0], y_test[7,:,:,0])

# %%
predict_evaluation(predict[8,:,:,0], X_test[8,:,:,0], y_test[8,:,:,0])

# %%
predict_evaluation(predict[9,:,:,0], X_test[9,:,:,0], y_test[9,:,:,0])
